# %% [markdown]
# # 🏠 Pandas Module import

# %%
import pandas as pd

# %% [markdown]
#  데이터프레임(DataFrame) 생성

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Score': [85, 90, 95]
}
df = pd.DataFrame(data)
df
# Out:
#       Name  Age  Score
# 0    Alice   25     85
# 1      Bob   30     90
# 2  Charlie   35     95

# %% [markdown]
#  데이터프레임 기본 정보 확인

# %%
print("\n🏷️ 데이터프레임 정보:")
print(df.info())  # 데이터 타입, 결측치 확인

print("\n🏷️ 데이터프레임 통계 요약:")
print(df.describe())  # 평균, 표준편차, 최소/최대값 등
# Out:
# 🏷️ 데이터프레임 정보:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   Score   3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 204.0+ bytes
# None
#
# 🏷️ 데이터프레임 통계 요약:
#         Age  Score
# count   3.0    3.0
# mean   30.0   90.0
# std     5.0    5.0
# min    25.0   85.0
# 25%    27.5   87.5
# 50%    30.0   90.0
# 75%    32.5   92.5
# max    35.0   95.0

# %% [markdown]
#  특정 열 선택

# %%
# Name 열만 선택
print(df['Name'])
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object

# %% [markdown]
#  특정 행 선택 (iloc: 인덱스 기준, loc: 이름 기준)

# %%
print(df.iloc[0])  # 첫 번째 행
print("="*3)
print(df.loc[df['Name'] == 'Bob']) # Bob이 포함된 행
# Out:
# Name     Alice
# Age         25
# Score       85
# Name: 0, dtype: object
# ===
#   Name  Age  Score
# 1  Bob   30     90

# %% [markdown]
#  새로운 열 추가

# %%
df['Passed'] = df['Score'] > 88  # 88점 이상이면 True
df
# Out:
#       Name  Age  Score  Passed
# 0    Alice   25     85   False
# 1      Bob   30     90    True
# 2  Charlie   35     95    True

# %% [markdown]
#  평균 나이 계산

# %%
df['Age'].mean()
# Out:
# np.float64(30.0)

# %% [markdown]
#  데이터 정렬 (Score 기준 내림차순)

# %%
df_sorted = df.sort_values(by='Score', ascending=False)
df_sorted
# Out:
#       Name  Age  Score  Passed
# 2  Charlie   35     95    True
# 1      Bob   30     90    True
# 0    Alice   25     85   False
