# %% [markdown]
# <a href="https://colab.research.google.com/github/fls2134/Session-2/blob/main/se2_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎇 Import Matplotlib Library

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# 선 그래프 (Line Plot)

# %%
# 데이터 생성
x = np.linspace(0, 10, 100)  # 0부터 10까지 100개의 점
y = np.sin(x)  # 사인 함수 값

# 그래프 그리기
plt.plot(x, y, label="sin(x)", color="b", linestyle="--")

# 제목 및 라벨 추가
plt.title("Sinusoidal Wave")  # 제목
plt.xlabel("X-axis")  # X축 라벨
plt.ylabel("Y-axis")  # Y축 라벨
plt.legend()  # 범례 표시
plt.grid(True)  # 격자 추가

# 그래프 출력
plt.show()

# %% [markdown]
# 막대 그래프 (Bar Chart)

# %%
# 데이터 생성
categories = ["A", "B", "C", "D"]
values = [10, 20, 15, 30]

# 그래프 그리기
plt.bar(categories, values, color=['tomato', 'skyblue', 'lightgreen', 'orange'])

# 제목 및 라벨 추가
plt.title("Bar Chart Example")
plt.xlabel("Categories")
plt.ylabel("Values")

# 그래프 출력
plt.show()

# %% [markdown]
# 산점도 (Scatter Plot)

# %%
# 랜덤 데이터 생성
np.random.seed(5)
x = np.random.rand(50)
y = np.random.rand(50)
colors = np.random.rand(50)

# 산점도 그리기
# plt.scatter(x, y, c=colors, cmap='viridis', alpha=0.7)
plt.scatter(x, y, c=colors, cmap='coolwarm', alpha=0.7)

# 제목 및 라벨 추가
plt.title("Scatter Plot Example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# 컬러바 추가
plt.colorbar(label="Color Intensity")

# 그래프 출력
plt.show()

# %% [markdown]
# 히스토그램 (Histogram)

# %%
# 랜덤 데이터 생성
data = np.random.randn(1000)  # 평균 0, 표준편차 1의 정규분포 데이터

# 히스토그램 그리기
plt.hist(data, bins=30, color="skyblue", range=[-5, 5], edgecolor="black")

# 제목 및 라벨 추가
plt.title("Histogram Example")
plt.xlabel("Value")
plt.ylabel("Frequency")

# 그래프 출력
plt.show()
